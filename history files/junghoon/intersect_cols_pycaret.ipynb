# %% [markdown]
# # Train데이터 불러오기
#
# 각 년도별 DataFrame을 리스트에 append합니다.
#
# 리스트 인덱스별로
#
# 0: 2017년도 데이터
#
# 1: 2018년도 데이터
#
# 2: 2019년도 데이터
#
# 3: 202년도 데이터
#
# 입니다

# %%
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm
import warnings
import os
warnings.filterwarnings(action='ignore')

# %%
RANDOM_STATE = 42
np.random.seed(42)

# %%
years = ["2017", "2018", "2019", "2020"]
date = "0105"
paths = [os.path.join('../data_' + date, 'train', 'KNOW_' + year + ".csv") for year in years]

know_train = [pd.read_csv(path) for path in paths]

# %%
know_train[0].head() # 2017년도 샘플
# Out:
#    aq27_1  aq9_1  aq39_1  bq19  aq17_1  aq36_2  aq31_1  bq22  aq19_2  bq18_7  \
# 0       4      2       5     2       5       4       3     5       2       3
# 1       2      1       2     2       3       4       3     6       0       4
# 2       2      3       1     2       3       4       3     5       4       4
# 3       4      5       4     1       2       4       4     6       2       3
# 4       2      1       2     2       3       3       1     3       0       4
#
#    ...  bq21  aq35_1  bq28  bq6  bq12_2  bq18_4  aq20_1  bq12_1  bq24_8  \
# 0  ...     3       3     3    5       3       3       5       4       2
# 1  ...     3       1     3    6       3       4       2       3       2
# 2  ...     2       3     2    6       4       4       3       3       2
# 3  ...     2       4     4    2       3       3       4       3       1
# 4  ...     2       1     3    6       3       4       2       3       2
#
#                                        text_response
# 0             자동차도장기능사 실무교육 생산 설비 자동화 없다 건설현장 노무직 없다
# 1                            건축전기설비기술사 건설 수주 드라이버 가위
# 2              건축전기설비기술사 신축 건설 경기 건축 설계 오토캐드 파이프 보일러
# 3  지적기사 측량 및 정보통신기술 교육 무량 감소 자동화 지적 기사 토탈 스테이션 무 ...
# 4         건축전기설비기술사 부동산 거품 건축 경기도 덩달아 불황 캐드 엑셀 건축 도면
#
# [5 rows x 147 columns]

# %%
know_train[1].head() # 2018년도 샘플
# Out:
#    bq26_4a  bq19  bq41_2  cq30  cq40  cq43  cq35  cq50_4  cq11  bq20  ...  \
# 0        1     1    3400     2     4     4     3       1     4     4  ...
# 1        0     2    1800     2     3     3     1       2     3     3  ...
# 2        0     1       0     4     1     4     1       1     1     4  ...
# 3        1     1    2750     2     4     3     4       1     2     4  ...
# 4        1     1    2300     2     1     3     3       1     3     4  ...
#
#    bq18  cq50_2  bq21  cq41  bq243  iq2  bq6  bq12_2  bq12_1  \
# 0     1       1    70     4      0    3    7       4       4
# 1     1       2   100     4      3    3    7       0       3
# 2     3       1     0     5      0    3    5       2       2
# 3     1       1    80     4      0    4    4       4       3
# 4     1       1    85     3      0    4    7       0       4
#
#                                        text_response
# 0  치과기공사 세라믹, 지르크니아 등 제작 방법, 프로그램 사용방법 직업 요구 증가 치...
# 1  정보처리기사 게임 개발 독학, 네트워크 기본 지식 게임 산업 축소 서브라임텍스트, ...
# 2                       대형화 추세 사장 망치 실리콘 사다리 유리칼 회사원
# 3                화학분석기능사 과학 발달 실험 검사 분석 보조 전자현미경 컴퓨터
# 4  치과기능사 고령화 틀니 인플란트등 의료 보험 보장 범위 확대 니켈, 크롬, 코발트 판매업
#
# [5 rows x 124 columns]

# %%
know_train[2].head() # 2019년도 샘플
# Out:
#    bq14_4  sq3  kq5_1  bq18_9  bq19  sq14  bq18_7  kq30_2  sq15  kq11_1  ...  \
# 0       4    4      2       2     3     4       1       5     4       4  ...
# 1       4    4      3       2     1     4       2       0     1       1  ...
# 2       4    2      2       2     1     2       2       0     2       1  ...
# 3       4    5      5       2     2     5       2       5     5       3  ...
# 4       3    4      4       2     2     3       2       0     1       1  ...
#
#    kq19_1  kq16_1  kq29_2  bq28  bq12_2  bq18_4  bq12_1  kq31_1  kq1_2  \
# 0       2       3       6     1       5       1       5       4      3
# 1       1       1       0     2       9       2       4       1      6
# 2       1       1       0     2       9       2       3       1      2
# 3       3       3       5     1       3       2       4       4      5
# 4       1       1       0     2       9       2       2       2      2
#
#                             text_response
# 0   전기철도자격증 전동차정비원 전동차 내부 익히기 사람 업무 수송 수요
# 1                 운송 시장 변화 컨테이너 대여사업,랜탈사업
# 2                                     숙박업
# 3  컴퓨터활용능력2급 행정사자격증 전산실무교육 처리 위해 문서 대행 업무
# 4                           일거리 용역회사(청소원)
#
# [5 rows x 134 columns]

# %%
know_train[3].head() # 2020년도 샘플
# Out:
#    saq41_1  saq21_1  bq14_4  bq18_9  saq20_1  saq41_2  vq2  bq19  saq42_2  \
# 0        2        3       5       2        4        3    4     1        4
# 1        4        4       3       2        4        5    4     1        4
# 2        3        4       4       2        3        4    4     2        5
# 3        3        3       4       2        3        3    4     1        0
# 4        3        4       3       2        5        5    3     2        5
#
#    saq37_1  ...  saq3_2  bq28  bq6  bq12_2  bq18_4  saq10_2  bq22_3  bq12_1  \
# 0        1  ...       5     1    7       3       2        0       4       3
# 1        3  ...       5     1    4       5       2        5       3       5
# 2        3  ...       4     1    5       4       1        5       5       4
# 3        2  ...       3     1    4       3       2        0       7       4
# 4        1  ...       5     1    7       4       2        5       7       3
#
#    bq22_1                                     text_response
# 0       5                        보건교사 자격증 간호사 자격증 인원 일자리 변화
# 1       3                                   법무사 현장 업무 경기 침체
# 2       5                              장비 기술 도입 전체 경기 악화 때문
# 3       6  보건교사 자격증 기초보건교육, 인성교육 사람 상태 소통 확인 가의 처방 일이 대체 불가
# 4       8                                     건축기사 건설 경기 침체
#
# [5 rows x 180 columns]

# %%
know_train[0].shape
# Out:
# (9486, 147)

# %%
know_train[1].shape
# Out:
# (9072, 124)

# %%
know_train[2].shape
# Out:
# (8555, 134)

# %%
know_train[3].shape
# Out:
# (8122, 180)

# %%
len(know_train[0]['knowcode'].unique())
# Out:
# 538

# %%
len(know_train[1]['knowcode'].unique())
# Out:
# 576

# %%
len(know_train[2]['knowcode'].unique())
# Out:
# 559

# %%
len(know_train[3]['knowcode'].unique())
# Out:
# 537

# %% [markdown]
# ## 네 df에 공통되는 column 추출

# %%
intersect01 = np.intersect1d(know_train[0].columns, know_train[1].columns)
intersect12 = np.intersect1d(know_train[1].columns, know_train[2].columns)
intersect23 = np.intersect1d(know_train[2].columns, know_train[3].columns)
intersect30 = np.intersect1d(know_train[3].columns, know_train[0].columns)

# %%
intersect01
# Out:
# array(['bq1', 'bq10', 'bq11', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_4',
#        'bq12_5', 'bq13', 'bq14', 'bq16', 'bq17', 'bq19', 'bq2', 'bq20',
#        'bq21', 'bq25', 'bq27', 'bq3', 'bq38', 'bq38_1', 'bq41_1',
#        'bq41_2', 'bq41_3', 'bq5', 'bq6', 'bq7', 'bq8_1', 'bq8_2', 'bq8_3',
#        'bq9', 'idx', 'knowcode', 'text_response'], dtype=object)

# %%
intersect12
# Out:
# array(['bq1', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_5', 'bq15', 'bq17',
#        'bq19', 'bq2', 'bq3', 'bq5', 'bq8_1', 'bq8_2', 'idx', 'knowcode',
#        'text_response'], dtype=object)

# %%
intersect23
# Out:
# array(['bq1', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_5', 'bq13_1', 'bq13_2',
#        'bq13_3', 'bq14_1', 'bq14_2', 'bq14_3', 'bq14_4', 'bq14_5', 'bq15',
#        'bq16_1', 'bq16_2', 'bq16_3', 'bq16_4', 'bq16_5', 'bq17', 'bq18_1',
#        'bq18_2', 'bq18_3', 'bq18_4', 'bq18_5', 'bq18_6', 'bq18_7',
#        'bq18_8', 'bq18_9', 'bq19', 'bq2', 'bq21_1', 'bq21_2', 'bq26',
#        'bq27_1', 'bq28', 'bq29', 'bq3', 'bq4', 'bq5', 'bq5_1', 'bq8_1',
#        'bq8_2', 'idx', 'knowcode', 'text_response'], dtype=object)

# %%
intersect30
# Out:
# array(['bq1', 'bq10', 'bq11', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_4',
#        'bq12_5', 'bq17', 'bq18_1', 'bq18_2', 'bq18_3', 'bq18_4', 'bq18_5',
#        'bq18_6', 'bq18_7', 'bq19', 'bq2', 'bq20', 'bq25', 'bq26', 'bq28',
#        'bq29', 'bq3', 'bq4', 'bq5', 'bq5_1', 'bq6', 'bq7', 'bq8_1',
#        'bq8_2', 'bq8_3', 'bq9', 'idx', 'knowcode', 'text_response'],
#       dtype=object)

# %%
intersect_between1 = np.intersect1d(intersect01, intersect12)
intersect_between2 = np.intersect1d(intersect23, intersect30)
intersect_all = np.intersect1d(intersect_between1,intersect_between2)
intersect_all
# Out:
# array(['bq1', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_5', 'bq17', 'bq19',
#        'bq2', 'bq3', 'bq5', 'bq8_1', 'bq8_2', 'idx', 'knowcode',
#        'text_response'], dtype=object)

# %%
len(intersect_all)
# Out:
# 15

# %% [markdown]
# ## merge df

# %%
train_df = pd.concat([know_train[0], know_train[1], know_train[2], know_train[3]], join='inner')
train_df
# Out:
#       bq19  bq5  bq1  bq12_3  bq8_1  bq3  bq2  bq17    idx  bq8_2  knowcode  \
# 0        2    1    3       4      4    6    1     2      0      3    825101
# 1        2    2   13       4      4    3    1     3      1      3    140204
# 2        2    2   13       4      4    3    1     3      2      4    140204
# 3        1    1   13       3      4    6    2     3      3      3    140601
# 4        2    2    6       4      4    4    1     3      4      2    140204
# ...    ...  ...  ...     ...    ...  ...  ...   ...    ...    ...       ...
# 8117     2    2   13       4      3    5    2     4  35244      5    121105
# 8118     1    2   11       4      3    2    1     4  35245      2     26102
# 8119     1    2   11       3      4    3    1     5  35246      3     31301
# 8120     2    2    3       3      4    2    1     5  35247      4    154105
# 8121     2    2    9       4      3    2    1     5  35248      3     14201
#
#       bq12_5  bq12_2  bq12_1  \
# 0          4       3       4
# 1          3       3       3
# 2          3       4       3
# 3          3       3       3
# 4          3       3       3
# ...      ...     ...     ...
# 8117       3       3       5
# 8118       3       2       3
# 8119       4       3       4
# 8120       3       3       3
# 8121       3       3       2
#
#                                           text_response
# 0                자동차도장기능사 실무교육 생산 설비 자동화 없다 건설현장 노무직 없다
# 1                               건축전기설비기술사 건설 수주 드라이버 가위
# 2                 건축전기설비기술사 신축 건설 경기 건축 설계 오토캐드 파이프 보일러
# 3     지적기사 측량 및 정보통신기술 교육 무량 감소 자동화 지적 기사 토탈 스테이션 무 ...
# 4            건축전기설비기술사 부동산 거품 건축 경기도 덩달아 불황 캐드 엑셀 건축 도면
# ...                                                 ...
# 8117                                      건설 경기 어려움 어려움
# 8118                                        광고 홍보 관련 시장
# 8119                                     보험계리사 보험 계속 필요
# 8120                               화학분석기능사 인구 수명 개발 갈수록
# 8121                                 서비스 향상 상품 다변 인구 감소
#
# [35235 rows x 15 columns]

# %%
train_df['year'] = 2017
train_df.loc[train_df['idx'] >= 9486, 'year'] = 2018
train_df.loc[train_df['idx'] >= 18569, 'year'] = 2019
train_df.loc[train_df['idx'] >= 27217, 'year'] = 2020

# %%
train_df.loc[train_df['idx'] >= 9486]
# Out:
#       bq19  bq5  bq1  bq12_3  bq8_1  bq3  bq2  bq17    idx  bq8_2  knowcode  \
# 0        1    1    3       4      4    2    1     1   9486      4    306301
# 1        2    1   10       5      3    2    1     1   9487      4    133204
# 2        1    2    6       2      3    1    1     2   9488      2    702502
# 3        1    2   13       4      4    2    5     1   9489      5    121201
# 4        1    2    3       4      4    2    1     1   9490      4    306301
# ...    ...  ...  ...     ...    ...  ...  ...   ...    ...    ...       ...
# 8117     2    2   13       4      3    5    2     4  35244      5    121105
# 8118     1    2   11       4      3    2    1     4  35245      2     26102
# 8119     1    2   11       3      4    3    1     5  35246      3     31301
# 8120     2    2    3       3      4    2    1     5  35247      4    154105
# 8121     2    2    9       4      3    2    1     5  35248      3     14201
#
#       bq12_5  bq12_2  bq12_1  \
# 0          4       4       4
# 1          5       0       3
# 2          2       2       2
# 3          4       4       3
# 4          4       0       4
# ...      ...     ...     ...
# 8117       3       3       5
# 8118       3       2       3
# 8119       4       3       4
# 8120       3       3       3
# 8121       3       3       2
#
#                                           text_response  year
# 0     치과기공사 세라믹, 지르크니아 등 제작 방법, 프로그램 사용방법 직업 요구 증가 치...  2018
# 1     정보처리기사 게임 개발 독학, 네트워크 기본 지식 게임 산업 축소 서브라임텍스트, ...  2018
# 2                          대형화 추세 사장 망치 실리콘 사다리 유리칼 회사원  2018
# 3                   화학분석기능사 과학 발달 실험 검사 분석 보조 전자현미경 컴퓨터  2018
# 4     치과기능사 고령화 틀니 인플란트등 의료 보험 보장 범위 확대 니켈, 크롬, 코발트 판매업  2018
# ...                                                 ...   ...
# 8117                                      건설 경기 어려움 어려움  2020
# 8118                                        광고 홍보 관련 시장  2020
# 8119                                     보험계리사 보험 계속 필요  2020
# 8120                               화학분석기능사 인구 수명 개발 갈수록  2020
# 8121                                 서비스 향상 상품 다변 인구 감소  2020
#
# [25749 rows x 16 columns]

# %%
train_df.loc[train_df['idx'] >= 18569]
# Out:
#       bq19  bq5  bq1  bq12_3  bq8_1  bq3  bq2  bq17    idx  bq8_2  knowcode  \
# 0        3    1   15       4      4    4    2     2  18569      4    812301
# 1        1    2    8       9      4    3    1     3  18570      3     15201
# 2        1    2    1       9      4    1    4     1  18571      4    901101
# 3        2    1   15       3      5    2    1     4  18572      5     29903
# 4        2    2   19       9      2    1    4     3  18573      2    561401
# ...    ...  ...  ...     ...    ...  ...  ...   ...    ...    ...       ...
# 8117     2    2   13       4      3    5    2     4  35244      5    121105
# 8118     1    2   11       4      3    2    1     4  35245      2     26102
# 8119     1    2   11       3      4    3    1     5  35246      3     31301
# 8120     2    2    3       3      4    2    1     5  35247      4    154105
# 8121     2    2    9       4      3    2    1     5  35248      3     14201
#
#       bq12_5  bq12_2  bq12_1                           text_response  year
# 0          4       5       5   전기철도자격증 전동차정비원 전동차 내부 익히기 사람 업무 수송 수요  2019
# 1          4       9       4                 운송 시장 변화 컨테이너 대여사업,랜탈사업  2019
# 2          3       9       3                                     숙박업  2019
# 3          4       3       4  컴퓨터활용능력2급 행정사자격증 전산실무교육 처리 위해 문서 대행 업무  2019
# 4          2       9       2                           일거리 용역회사(청소원)  2019
# ...      ...     ...     ...                                     ...   ...
# 8117       3       3       5                           건설 경기 어려움 어려움  2020
# 8118       3       2       3                             광고 홍보 관련 시장  2020
# 8119       4       3       4                          보험계리사 보험 계속 필요  2020
# 8120       3       3       3                    화학분석기능사 인구 수명 개발 갈수록  2020
# 8121       3       3       2                      서비스 향상 상품 다변 인구 감소  2020
#
# [16677 rows x 16 columns]

# %%
train_df.loc[train_df['idx'] >= 27217]
# Out:
#       bq19  bq5  bq1  bq12_3  bq8_1  bq3  bq2  bq17    idx  bq8_2  knowcode  \
# 90       5    1   18       4      4    6    2     4  27217      4    420201
# 91       5    2    7       3      2    2    1     3  27218      2    615701
# 92       1    1    3       3      3    6    1     3  27219      4    152201
# 93       2    1    6       4      3    5    1     5  27220      3    140201
# 94       1    1   16       4      4    3    5     5  27221      4    304003
# ...    ...  ...  ...     ...    ...  ...  ...   ...    ...    ...       ...
# 8117     2    2   13       4      3    5    2     4  35244      5    121105
# 8118     1    2   11       4      3    2    1     4  35245      2     26102
# 8119     1    2   11       3      4    3    1     5  35246      3     31301
# 8120     2    2    3       3      4    2    1     5  35247      4    154105
# 8121     2    2    9       4      3    2    1     5  35248      3     14201
#
#       bq12_5  bq12_2  bq12_1  \
# 90         4       4       4
# 91         3       2       2
# 92         4       3       3
# 93         3       3       3
# 94         4       1       4
# ...      ...     ...     ...
# 8117       3       3       5
# 8118       3       2       3
# 8119       4       3       4
# 8120       3       3       3
# 8121       3       3       2
#
#                                           text_response  year
# 90                                           훈련교육 인원 제약  2020
# 91                            자동화 기계 등장 셀프 유기 자동화 기계 등장  2020
# 92                      금속재료기사 자격증 실무교육 사람 직접 분석 결괄르 작성  2020
# 93          건축구조기술자 건축기사 산업기사 각 분야의 기술자들과 소통을 해야함 현재 변동  2020
# 94    간호사 자격증 보건교사 자격증 보건교육, 성교육의 방법과 기술 , 학교에서 실시 가...  2020
# ...                                                 ...   ...
# 8117                                      건설 경기 어려움 어려움  2020
# 8118                                        광고 홍보 관련 시장  2020
# 8119                                     보험계리사 보험 계속 필요  2020
# 8120                               화학분석기능사 인구 수명 개발 갈수록  2020
# 8121                                 서비스 향상 상품 다변 인구 감소  2020
#
# [8032 rows x 16 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35235 entries, 0 to 8121
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bq19           35235 non-null  int64
#  1   bq5            35235 non-null  int64
#  2   bq1            35235 non-null  int64
#  3   bq12_3         35235 non-null  int64
#  4   bq8_1          35235 non-null  int64
#  5   bq3            35235 non-null  int64
#  6   bq2            35235 non-null  int64
#  7   bq17           35235 non-null  int64
#  8   idx            35235 non-null  int64
#  9   bq8_2          35235 non-null  int64
#  10  knowcode       35235 non-null  int64
#  11  bq12_5         35235 non-null  int64
#  12  bq12_2         35235 non-null  int64
#  13  bq12_1         35235 non-null  int64
#  14  text_response  34785 non-null  object
#  15  year           35235 non-null  int64
# dtypes: int64(15), object(1)
# memory usage: 4.6+ MB

# %% [markdown]
# # 전처리
#
# 데이터의 빈 셀에 None값이 아닌 ' '처럼 공백으로 들어가있기 때문에 is_null등의 함수로 결측치를 찾아낼 수 없습니다.
#
# 공백이 있는 컬럼은 NaN으로 대체하였습니다.

# %%
#for col in train_df.columns:
#        train_df[col].replace(' ', np.NaN, inplace=True)

# %% [markdown]
# ## pycaret 소환

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35235 entries, 0 to 8121
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bq19           35235 non-null  int64
#  1   bq5            35235 non-null  int64
#  2   bq1            35235 non-null  int64
#  3   bq12_3         35235 non-null  int64
#  4   bq8_1          35235 non-null  int64
#  5   bq3            35235 non-null  int64
#  6   bq2            35235 non-null  int64
#  7   bq17           35235 non-null  int64
#  8   idx            35235 non-null  int64
#  9   bq8_2          35235 non-null  int64
#  10  knowcode       35235 non-null  int64
#  11  bq12_5         35235 non-null  int64
#  12  bq12_2         35235 non-null  int64
#  13  bq12_1         35235 non-null  int64
#  14  text_response  34785 non-null  object
#  15  year           35235 non-null  int64
# dtypes: int64(15), object(1)
# memory usage: 4.6+ MB

# %%
# object_cols = ['bq4', 'bq4_1a', 'bq4_1b', 'bq4_1c', 'bq5', 'bq5_1', 'bq5_2', 'bq6', 'bq7',
#                'bq8_3', 'bq9', 'bq10', 'bq11', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_4', 'bq12_5',
#                'bq20', 'bq25', 'bq28', 'bq29',
#               ]

# %%
train_df.shape
# Out:
# (35235, 16)

# %%
from pycaret.classification import *

# %%
train_df.columns
# Out:
# Index(['bq19', 'bq5', 'bq1', 'bq12_3', 'bq8_1', 'bq3', 'bq2', 'bq17', 'idx',
#        'bq8_2', 'knowcode', 'bq12_5', 'bq12_2', 'bq12_1', 'text_response',
#        'year'],
#       dtype='object')

# %%
for col in train_df.columns:
    print(col)
    print(train_df[col].value_counts())
# Out:
# bq19
# 2    13918
# 1    11972
# 3     6245
# 4     2773
# 5      324
# 0        3
# Name: bq19, dtype: int64
# bq5
# 2    19138
# 1    16078
# 0       10
# 3        6
# 6        2
# 4        1
# Name: bq5, dtype: int64
# bq1
# 3     6108
# 13    3624
# 18    3225
# 15    3029
# 17    2794
# 19    2363
# 6     2313
# 16    2154
# 10    2034
# 7     1526
# 8     1524
# 11    1262
# 9      857
# 14     670
# 1      598
# 4      530
# 20     228
# 5      194
# 12     100
# 2       96
# 21       6
# Name: bq1, dtype: int64
# bq12_3
# 3       13448
# 4       12129
# 5        2482
# 0        2351
# 9        2348
# 2        2135
# 1         341
# 4300        1
# Name: bq12_3, dtype: int64
# bq8_1
# 4     15879
# 3     12105
# 5      3453
# 2      3298
# 1       499
# 30        1
# Name: bq8_1, dtype: int64
# bq3
# 2    14483
# 1     6180
# 4     4217
# 3     4206
# 5     3412
# 6     2737
# Name: bq3, dtype: int64
# bq2
# 1    21876
# 2     5530
# 4     4083
# 5     2069
# 3     1462
# 6      215
# Name: bq2, dtype: int64
# bq17
# 3    11724
# 4     7407
# 1     7288
# 2     6389
# 5     2424
# 0        3
# Name: bq17, dtype: int64
# idx
# 2047     1
# 5448     1
# 9550     1
# 15693    1
# 13644    1
#         ..
# 6838     1
# 4791     1
# 27320    1
# 25273    1
# 0        1
# Name: idx, Length: 35235, dtype: int64
# bq8_2
# 3    12831
# 4    11043
# 2     6593
# 1     2430
# 5     2338
# Name: bq8_2, dtype: int64
# knowcode
# 9999999    382
# 212101     182
# 211101     151
# 13305      150
# 301004     139
#           ...
# 153204      15
# 154105      15
# 307102      15
# 121106      15
# 13304        8
# Name: knowcode, Length: 585, dtype: int64
# bq12_5
# 3    15942
# 4    15206
# 5     1957
# 2     1938
# 1      191
# 0        1
# Name: bq12_5, dtype: int64
# bq12_2
# 3     15294
# 4      8136
# 2      4112
# 0      2804
# 9      2657
# 5      1334
# 1       895
# 44        2
# 29        1
# Name: bq12_2, dtype: int64
# bq12_1
# 3    16168
# 4    10773
# 2     5896
# 5     1544
# 1      853
# 0        1
# Name: bq12_1, dtype: int64
# text_response
# 변화                                              121
# 상태 유지                                           112
# 인구 감소                                            36
# 박사학위 상태 유지                                       29
# 기계 자동화                                           27
#                                                ...
# 기계화 설비 자동화 정기 미기 없다 없다 없다                         1
# 의사면허증 인구 감소 선생님 컴퓨터 청진기 레이져 기계 없다 없다 없다           1
# 서류작업 및 업무 인수인계 처풀산 인구 감소 선생님 프로그램 운동선수 없음 없음      1
# 섬유공장현장직                                           1
# 조명설치방법 드론 촬영 장비 다양 화로                             1
# Name: text_response, Length: 33538, dtype: int64
# year
# 2017    9486
# 2018    9072
# 2019    8645
# 2020    8032
# Name: year, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = setup(train_df, target = 'knowcode', 
            fold = 3,
            numeric_features = ['bq19', 'bq12_1', 'bq8_1', 'bq3', 'bq17', 'bq8_2', 'bq12_5', 'year'],
            categorical_features = ['bq12_3', 'bq12_2', 'bq5', 'bq1', 'bq2'],
            ignore_features = ['idx', 'text_response'],
            session_id=RANDOM_STATE)
# Out:
# <style  type="text/css" >
# #T_6aae6701_6e32_11ec_9522_f8633f09c93brow5_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_6aae6701_6e32_11ec_9522_f8633f09c93b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow1_col1" class="data row1 col1" >knowcode</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow4_col1" class="data row4 col1" >(35235, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow5_col1" class="data row5 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow6_col1" class="data row6 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow11_col1" class="data row11 col1" >(24664, 57)</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow12_col1" class="data row12 col1" >(10571, 57)</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow16_col1" class="data row16 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_6aae6701_6e32_11ec_9522_f8633f09c93blevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93brow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_6aae6701_6e32_11ec_9522_f8633f09c93bro

# %%
compare_models(exclude=['lr'])
# Out:
# IntProgress(value=0, description='Processing: ', max=9)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  23:22:31
# Status     . . . . . . . . . . . . . . . . . .    Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <style  type="text/css" >
#     #T_5c08cefb_6e33_11ec_82d3_f8633f09c93b th {
#           text-align: left;
#     }#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col0,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col1,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col2,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col3,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col4,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col5,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col6,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col7,#T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col8{
#             text-align:  left;
#         }</style><table id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93blevel0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col3" class="data row0 col3" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col6" class="data row0 col6" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col7" class="data row0 col7" >0.0000</td>
#                         <td id="T_5c08cefb_6e33_11ec_82d3_f8633f09c93brow0_col8" class="data row0 col8" >24.1667</td>
#             </tr>
#     </tbody></table>
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-40-8467fd9aa464> in <module>
# ----> 1 compare_models(include=['rf'])
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, verbose)
#     769     """
#     770
# --> 771     return pycaret.internal.tabular.compare_models(
#     772         include=include,
#     773         exclude=exclude,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\tabular.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, verbose, display)
#    2303                 display.update_monitor(2, _get_model_name(model))
#    2304                 display.display_monitor()
# -> 2305                 model, model_fit_time = create_model_supervised(
#    2306                     estimator=model,
#    2307                     system=False,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\tabular.py in create_model_supervised(estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, verbose, system, X_train_data, y_train_data, metrics, display, **kwargs)
#    3046             model_fit_start = time.time()
#    3047             with io.capture_output():
# -> 3048                 pipeline_with_model.fit(data_X, data_y, **fit_kwargs)
#    3049             model_fit_end = time.time()
#    3050
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\pipeline.py in fit(self, X, y, **fit_kwargs)
#     116
#     117     def fit(self, X, y=None, **fit_kwargs):
# --> 118         result = super().fit(X, y=y, **fit_kwargs)
#     119
#     120         self._carry_over_final_estimator_fit_vars()
#
# ~\anaconda3\lib\site-packages\imblearn\pipeline.py in fit(self, X, y, **fit_params)
#     279                                  self._log_message(len(self.steps) - 1)):
#     280             if self._final_estimator != "passthrough":
# --> 281                 self._final_estimator.fit(Xt, yt, **fit_params)
#     282         return self
#     283
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~\anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# ~\anaconda3\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __call__(self, *args, **kwargs)
#     593     def __call__(self, *args, **kwargs):
#     594         try:
# --> 595             return self.func(*args, **kwargs)
#     596         except KeyboardInterrupt as e:
#     597             # We capture the KeyboardInterrupt and reraise it as
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 153354240 bytes

# %%
from sklearn.model_selection import train_test_split

# %%
from catboost import CatBoostClassifier

cat = CatBoostClassifier()

cat.fit()

# %% [markdown]
# # 전처리
#
# 데이터의 빈 셀에 None값이 아닌 ' '처럼 공백으로 들어가있기 때문에 is_null등의 함수로 결측치를 찾아낼 수 없습니다.
#
# 공백이 있는 컬럼은 '0'으로 대체하였습니다.

# %%
for df in know_train:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# ## 라벨 인코딩
#
# 숫자로 변환할 수 있는 컬럼은 라벨 인코딩을 사용하지 않았습니다.
#
# string이나 object컬럼은 라벨인코더를 이용해 변환하였으며 추후 test셋에 사용해야하기 때문에 년도별, 컬럼별로 dictionary를 이용해 저장하였습니다

# %%
from sklearn.preprocessing import LabelEncoder
years = ['2017', '2018', '2019', '2020']

year_encoder = {}

for year, df in zip(years, know_train):
    print(year)
    encoders = {}
    
    for col in df.columns:
        if col == 'idx':
            print("HEY")
            continue
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = LabelEncoder()
            df[col] = df[col].map(str)
            df[col] = encoder.fit_transform(df[col])
            encoders[col] = encoder
            
            
    year_encoder[year] = encoders

# %%
know_train[0]

# %%
know_train[1]

# %%
know_train[2]

# %%
know_train[3]

# %% [markdown]
# # X, y 구분 및 모델 학습
#
# 이번 대회에서 맞춰야 할 값은 knowcode입니다.
#
# ID와 knowcode를 제외한 나머지 feature를 X, knowcode를 정답 y로 두어 모델을 학습하였습니다.
#
# 베이스라인에서는 의사결정나무와 랜덤포레스트를 선정하였습니다

# %%
know_train[0].iloc[:, 1:-1]

# %%
train_data = {}
for year, df in zip(years, know_train):
    train_data[year] = {'X': df.iloc[:, 1:-1], # idx 제외
                        'y': df.iloc[:, -1]}

# %% [markdown]
# ## 의사결정나무

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

dt_models = {}

for year in tqdm(years):
    model = DecisionTreeClassifier(random_state=123456)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    dt_models[year] = model

# %% [markdown]
# ## 랜덤포레스트

# %%
rf_models = {}

for year in tqdm(years):
    model = RandomForestClassifier(n_estimators=100, random_state=123456, n_jobs=8)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    rf_models[year] = model

# %% [markdown]
# ## Testset 불러오기
#
# 마찬가지로 년도별로 DataFrame으로 불러온 후 리스트에 할당합니다.

# %%
TEST_PATH_2017 = "./KNOW_data/test/KNOW_2017_test.csv"
TEST_PATH_2018 = "./KNOW_data/test/KNOW_2018_test.csv"
TEST_PATH_2019 = "./KNOW_data/test/KNOW_2019_test.csv"
TEST_PATH_2020 = "./KNOW_data/test/KNOW_2020_test.csv"

TEST_PATHs = [TEST_PATH_2017, TEST_PATH_2018, TEST_PATH_2019, TEST_PATH_2020]

# %%
know_test = [pd.read_csv(path) for path in TEST_PATHs]
know_test[0].head() # 2017년도 test 샘플

# %% [markdown]
# Train set과 마찬가지로 평균, '0'으로 대체하였습니다

# %%
for df in know_test:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# Train에 사용하였던 라벨인코더를 이용해서 카테고리를 정수로 변환합니다.
#
# 만약 Test변수가 Train 라벨인코더의 클래스에 없을경우 -1로 처리합니다

# %%
years = ['2017', '2018', '2019', '2020']

for year, df in zip(years, know_test):
    print(year)
    encoders = {}
    
    for col in df.columns:
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = year_encoder[year][col]
            df[col] = df[col].map(str)
            category_map = {category: idx for idx, category in enumerate(encoder.classes_)}
            df[col] = df[col].apply(lambda x: category_map[x] if x in category_map else -1) # train set에서 보지못한 카테고리변수 -1(UNK) 처리

# %% [markdown]
# ### 데이터 처리 및 라벨인코딩 후

# %%
know_train[0]['aq1_1'].value_counts()

# %%
know_test[0].head() # 2017년도 test 샘플

# %% [markdown]
# ## 테스트셋 추출 및 학습
#
# ID 값을 제외한 나머지 데이터를 이용하여 모델에 넣어 추론합니다.

# %%
test_data = {}
for year, df in zip(years, know_test):
    test_data[year] =  {'X': df.iloc[:,1:]}

# %% [markdown]
# ### 의사결정나무로 예측

# %%
dt_predicts = [] 

for year in tqdm(years):
    pred = dt_models[year].predict(test_data[year]['X'])
    dt_predicts.extend(pred)

# %% [markdown]
# ### 랜덤포레스트로 예측

# %%
rf_predicts = [] 

for year in tqdm(years):
    pred = rf_models[year].predict(test_data[year]['X'])
    rf_predicts.extend(pred)

# %% [markdown]
# # 제출

# %%
submission = pd.read_csv('./KNOW_data/sample_submission.csv') # sample submission 불러오기

# %%
submission['knowcode'] = rf_predicts

submission.to_csv('submission_baseline.csv', index=False)
