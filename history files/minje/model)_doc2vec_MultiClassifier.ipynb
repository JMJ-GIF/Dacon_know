# %% [markdown]
# # Doc2vec MultiClassifier Model
#
# 1. 데이터
#     * data_0116를 사용함
#     * 텍스트로 이루어진 열을 하나의 열로 합쳐주고, Stopwards를 제거함
#
# 2. fitting
#     * STEP 1 : Major열을 기준으로 정합성을 테스트하고, 올바르지 못한것은 et로 예측할 것이므로 따로 빼두기 **(string_compare fitting)**
#     * STEP 2 : Major열과 description을 jaro_distance로 비교하여 유사도를 도출함 **(string_compare fitting)**
#     * STEP 3 : 전체 train 데이터를 기준으로 et_300으로 학습함 **(et fitting)**
#
# 3. Prediction
#     * STEP 1 : Similarity와 사전에 정한 threshold를 비교하여 높은 레코드에 대해서만 string_compare로 예측을 진행 **(string_compare predict)**
#     * STEP 2 : 그렇지 못한 데이터에 대해서는 et_300으로 예측값을 도출함 **(et predict)**

# %% [markdown]
# # 라이브러리 import & 데이터 로딩 & 전처리

# %%
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm
import warnings

RANDOM_STATE = 42
np.seed = 42
DATA_PATH = "../data_0116/"

warnings.filterwarnings(action='ignore')
PATH_2017 = DATA_PATH + "train/KNOW_2017.csv"
PATH_2018 = DATA_PATH + "train/KNOW_2018.csv"
PATH_2019 = DATA_PATH + "train/KNOW_2019.csv"
PATH_2020 = DATA_PATH + "train/KNOW_2020.csv"

paths = [PATH_2017, PATH_2018, PATH_2019, PATH_2020]

know_train = [pd.read_csv(path) for path in paths]

TEST_PATH_2017 = DATA_PATH + "test/KNOW_2017_test.csv"
TEST_PATH_2018 = DATA_PATH + "test/KNOW_2018_test.csv"
TEST_PATH_2019 = DATA_PATH + "test/KNOW_2019_test.csv"
TEST_PATH_2020 = DATA_PATH + "test/KNOW_2020_test.csv"

TEST_PATHs = [TEST_PATH_2017, TEST_PATH_2018, TEST_PATH_2019, TEST_PATH_2020]

know_test = [pd.read_csv(path) for path in TEST_PATHs]

# doc2vec을 사용할거라 txt열을 모두 하나로 모아줘야해요
text_info_cols = {"2017": ['sim_job','bef_job','able_job','major'],
                  "2018": ['sim_job','bef_job','able_job','major'],
                  "2019": ['bef_job','able_job','major'],
                  "2020": ['major'],}
years = ['2017','2018','2019','2020']

for i, year in enumerate(years):
    text_info_col = text_info_cols[year]
    for col in text_info_col:
        know_train[i]['text_response'] = know_train[i]['text_response'] + ' ' + know_train[i][col]
        know_test[i]['text_response'] = know_test[i]['text_response'] + ' ' + know_test[i][col]
    know_train[i].drop(text_info_col,axis=1, inplace=True)
    know_test[i].drop(text_info_col,axis=1, inplace=True)

# text_response 내 존재하는 stopwords들을 제거해줍시다
stopwords = ['없다','없음','0','모름','공란']
for i in tqdm(range(4)):
    for k, doc in enumerate(know_train[i]['text_response']):
        doc_list = doc.split(' ')
        new_list = [word for word in doc_list if word not in stopwords]
        new_string = ''
        for word in new_list:
            new_string += word
            new_string += ' '
        know_train[i].loc[k,'text_response'] = new_string[:-1]
    for k, doc in enumerate(know_test[i]['text_response']):
        doc_list = doc.split(' ')
        new_list = [word for word in doc_list if word not in stopwords]
        new_string = ''
        for word in new_list:
            new_string += word
            new_string += ' '
        know_test[i].loc[k,'text_response'] = new_string[:-1]
# Out:
# 100%|██████████| 4/4 [00:29<00:00,  7.43s/it]

# %% [markdown]
# # Fitting & Prediction

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

def doc2vec_train(know_train):
    '''
    
    모든 text열이 합쳐진 text_response에 대해, Doc2vec을 적용하고, tagging함.
    
    '''
    my_texts = know_train[['idx','text_response']]
    my_texts_and_tags = [(row.text_response, [str(row.idx)]) for row in my_texts.itertuples()]
    TRAIN_documents = [TaggedDocument(words=text, tags=tags) for text, tags in my_texts_and_tags]
    model = Doc2Vec(TRAIN_documents, vector_size=1000, window=4, epochs=40, min_count=0, workers=4)
    
    return model

def doc2vec_pred(know_train, know_test, model, viz = False):
    '''
     
    test set의 text_response와 가장 유사한 text_response를 train에서 찾음.
    해당 레코드의 knowcode를 prediction으로 생각함.
    
    '''
    Test_documents = [doc for doc in know_test['text_response']]
    
    pred_list = []
    sim_list = []
    for text in Test_documents:
        text_split = text.split(' ')
        inferred_v = model.infer_vector(text_split)
        most_similar_docs = model.docvecs.most_similar(positive=[inferred_v], topn=1)
        
        top1_train_idx = int(most_similar_docs[0][0])
        top1_sim = round(float(most_similar_docs[0][1]),2)
        sim_list.append(top1_sim)
        
        pred = list(know_train.loc[know_train['idx']==top1_train_idx]['knowcode'])[0]
        pred_list.append(pred)
        
    return pred_list, sim_list

# %%
# 4개년도 모델을 학습하고 저장합니다
models = []
for i in tqdm(range(4)):
    model = doc2vec_train(know_train[i])
    models.append(model)
# Out:
# 100%|██████████| 4/4 [05:49<00:00, 87.37s/it]

# %%
# 4개년도 데이터로 예측합니다
doc2vec_preds = []
for i in tqdm(range(4)):
    pred, _ = doc2vec_pred(know_train[i], know_test[i], models[i])
    doc2vec_preds.extend(pred)

# %%
submission = pd.read_csv('../data_0103/sample_submission.csv') # sample submission 불러오기
submission['knowcode'] = doc2vec_preds

submission.to_csv('doc2vec_data0116.csv', index=False)

# %% [markdown]
# # Result Preview
# > 성능이 안좋아서 어떻게 예측이 진행됐는지 눈으로 확인함

# %%
sims = []
for i in tqdm(range(4)):
    pred, sim = doc2vec_pred(know_train[i], know_test[i], models[i])
    sims.append(sim)
# Out:
# 100%|██████████| 4/4 [03:25<00:00, 51.44s/it]

# %%
# similarity가 다 너무 높게 나온다
# 뭔가 이상하다
for i in range(4):
    print(pd.Series(sims[i]).describe())
    print()
# Out:
# count    9486.000000
# mean        0.118696
# std         0.089266
# min         0.050000
# 25%         0.090000
# 50%         0.100000
# 75%         0.120000
# max         0.830000
# dtype: float64
#
# count    9069.000000
# mean        0.136223
# std         0.143112
# min         0.050000
# 25%         0.090000
# 50%         0.100000
# 75%         0.120000
# max         0.910000
# dtype: float64
#
# count    8554.000000
# mean        0.136568
# std         0.145903
# min         0.060000
# 25%         0.090000
# 50%         0.100000
# 75%         0.120000
# max         0.880000
# dtype: float64
#
# count    8122.000000
# mean        0.103090
# std         0.042041
# min         0.050000
# 25%         0.090000
# 50%         0.100000
# 75%         0.110000
# max         0.850000
# dtype: float64

# %%
train_data = know_train[0]
test_data = know_test[0]

Test_documents = [doc for doc in test_data['text_response']]
    
pred_list = []
sim_list = []
verbose_df = pd.DataFrame(index=range(len(Test_documents)))
for i,text in enumerate(Test_documents):
    text_split = text.split(' ')
    inferred_v = models[0].infer_vector(text_split)
    most_similar_docs = models[0].docvecs.most_similar(positive=[inferred_v], topn=1)
    
    top1_train_idx = int(most_similar_docs[0][0])
    top1_sim = round(float(most_similar_docs[0][1]),2)
    sim_list.append(top1_sim)
    top1_train_desc = list(train_data.loc[train_data['idx']==top1_train_idx]['text_response'])[0]
    
    pred = list(train_data.loc[train_data['idx']==top1_train_idx]['knowcode'])[0]
    pred_list.append(pred)
    
    test_idx = test_data.loc[i,'idx']
    
    verbose_df.loc[i,'test_idx'] = test_idx
    verbose_df.loc[i,'sim_train_idx'] = top1_train_idx
    verbose_df.loc[i,'sim_train_desc'] = top1_train_desc
    verbose_df.loc[i,'sim_test_desc'] = test_data.loc[i,'text_response']
    verbose_df.loc[i,'similarity'] = top1_sim

# %%
# Doc2vec이 제대로 이루어지지 않음을 볼 수 있다. 해당 모델은 쓰기 힘들 것으로 생각된다.
verbose_df.head(49)
# Out:
#     test_idx  sim_train_idx  \
# 0        0.0         7617.0
# 1        1.0         4793.0
# 2        2.0         1938.0
# 3        3.0         8790.0
# 4        4.0         3111.0
# 5        5.0         6459.0
# 6        6.0         6707.0
# 7        7.0         4504.0
# 8        8.0         5683.0
# 9        9.0         4676.0
# 10      10.0         7350.0
# 11      11.0         2685.0
# 12      12.0         5386.0
# 13      13.0         4696.0
# 14      14.0         5874.0
# 15      15.0         7329.0
# 16      16.0          246.0
# 17      17.0         3404.0
# 18      18.0         1700.0
# 19      19.0          747.0
# 20      20.0         4861.0
# 21      21.0         1896.0
# 22      22.0         2016.0
# 23      23.0         7087.0
# 24      24.0         3408.0
# 25      25.0         6126.0
# 26      26.0         6591.0
# 27      27.0         2147.0
# 28      28.0         8131.0
# 29      29.0         3079.0
# 30      30.0         9092.0
# 31      31.0         4532.0
# 32      32.0         4730.0
# 33      33.0         2924.0
# 34      34.0         5678.0
# 35      35.0         7477.0
# 36      36.0         6651.0
# 37      37.0         5612.0
# 38      38.0         1558.0
# 39      39.0         1081.0
# 40      40.0         8800.0
# 41      41.0         3878.0
# 42      42.0         2218.0
# 43      43.0         3112.0
# 44      44.0         8970.0
# 45      45.0         6591.0
# 46      46.0         7120.0
# 47      47.0         6309.0
# 48      48.0          720.0
#
#                                        sim_train_desc  \
# 0                     해외정서및 기본소양교육 변화 사무관, 서기관, 대사 정외
# 1        영상 방송에 관한 업무 미디어 시대 도래 카메라 컴퓨터 플래시 감독님 방송미디어
# 2           교육전도사 과정 교인 감소 요인 인구 감소 성경책 주석 십자가 자영업 신학
# 3   치과의면허 고령화 노련 증가 보철 인플란트 분야 수요 증가 치과 광중 압기 미세 현...
# 4         운전면허증 대중교통 이용 때문 자동차 카카오 택시 어플 택시기사 자영업 기계과
# 5   디지털포렌식 CCFP 정보보안기사 정보과자격증 필요 사이버 범죄를 수사라는 기법교육...
# 6                                 회계 무량 전산 회계 프로그램 회계
# 7            치기공사 수요 처가 보험 석고 모형 마스크 프레 사무직 치위생사 치기공학
# 8   바둑기사 자격증 한국기원의 기사선발전 통해 입단 기원들 간의 교류 온라인게임 바둑 ...
# 9     실무와 관련된 시험에 대한 교육 매출 일지 포화상태 발열 장비 원소 석기 엑셀 화학과
# 10                                     소수 인력 보유 변동 상업
# 11  의료코디네이터 의료시장에 대한 이해 우리나라 의료 시설 때문 외국인 컴퓨터 코디 선...
# 12  조립하거나 수동공구 사용법 조립 동력공구 이용법을 훈련교육함 작업 변화 단기 딩기 ...
# 13                      업종 큰물 변화 컴퓨터 판매 마법사 프로그램 전자공학
# 14     숙련기간 전자제품 가격 하락 수리 구입 증가 드라이버 접착제 광택 공구 장갑 인문계
# 15  산업기사 사진 보정합성 훈련 디지털 카메라 사용 별도 현상 인화 파일 형태 보관 경...
# 16  의사면허 내과전문의 레지던트 인턴과정 고령화 때문 의사 수가 증가 생각 차트 전문의...
# 17  ERP정보관리사 회계사 회사시스템에 맞춘 회계업무 숙지 전문화 재무 인력 필요 사회...
# 18                              전문 전통 직종 계속 유지됨 무용 무용
# 19       화가 조각가 관련 실습 개개인 작품 통해 수익 조각가 증가 감소 마기 망치 조소
# 20    강사자격증 직업 특성 수요 대비 공급 마이크 칠판 수첩 교재 가발 강사님 미용사 인문
# 21  항공기 정비사 고장부위 분해 수리오는 부품교체의 필요성 판단 작동상태 평가훈련교육 ...
# 22       전자산업기사 완제품 검사 방법 일자리 업종 테스 터기 전동 공구 측정 장비 전기
# 23              임상가공산업기사 목재가공기능사 공장 해외진출 설비 목기 건조기 기계
# 24  프로 구단 추세 야구공 야구 배트 내야수 글러브 스파이크 운동화 유니폼 배팅 장갑 ...
# 25               기자재훈련 정부 기관 연관 사업 승기 원심분리기 연구보조원 생물학
# 26                                                 일이
# 27  일식조리기능사 양식조리기능사 시다생활을 보조 하면서 실력을 쌓아야한다 음식 점등 도...
# 28  관세법숙지 외국환거래법 회계문서정리 수출입문서작성 채용 감소 사회 환경 변화 통관 ...
# 29  수질환경기사 폐기물기사 수질환경법과 현장에서의 대처능력 대한 인식 수준 갈수록 서울...
# 30          대본과 관련된 전문지신 지방자치단체 축제 활성화 대본 무대 조감독 방송연예
# 31  식물보호기사 유기농업기사 특정작목에 대한 전문지식 현장기술습득 호도 행정 시스템 프...
# 32  방송장비별 특성과 기능 기술 발전 소요 인력 감소 문서 작성 도면 작성 프로그램 S...
# 33          전기자격증 관리사 관리업무에 대해서 아파트 컴퓨터 복사기 소장 사무원 전기
# 34  동물의 성격 습성을 알아야해서 동물 사랑 인구 증가 온도계 지휘봉 박계스 박대 동물자원학
# 35  직업상담사 워드프로세서 컴퓨터활용능력 2급 민원응대 직무관련교육 노동법교육 상담심리...
# 36                         방사선사 의료 기술 발전 레이 촬영 장치 방사선
# 37                            로더운전기사 건설 경기 악화 불도저 상업고
# 38  동물조련사 공연 동물 훈련 조련 여가 생활 동물 공연 조련사 수요 채찍 호루라기 동...
# 39                    사상공정실습 신입 희망 산업 자체 캐드 도면 기능공 농업
# 40  승강기 기능사 현장 위치 고장 수리엔 관한 지식 승강기 설치량 보임 무량 증가 엘레...
# 41      금융 관련 업무 때문 변동 계속 일자리 이기 때문 컴퓨터 상담원 보험설계 경영학과
# 42                           농어 어르신 고령화 농기 설명 자영업 경영학
# 43  제작 관한 기기 기구 재료 등에 대한 교육 업무 대비 임금 컴퓨터 캐드 무대감독 보...
# 44                   폐기물처리기사자격증 환경 생각 제품 폐기물처리사 화학공학과
# 45                                                 일이
# 46          미디어 발전 시보 분야 관심 가지 노트 국어사전 컴퓨터 편의점 자영업 국문
# 47                치과기공사 평균수명 연장 보철 마스크 안경 학생 기공소 치기공학
# 48  학예사 큐레이팅 작품디스플레이 기획 문화 향상 공유 그림 작품설치기사 갤러리스트 대...
#
#                                         sim_test_desc  similarity
# 0                                       대체 업무 컴퓨터 비서학        0.10
# 1              품질관리기사 실무교육 제조업 생각 때문 제품 검사 시스템 엑셀 농화학        0.11
# 2   기획력 현장경험 미디어 증가 오디션 편집 프로그램 홀로 방송 진행 장비 1인 미디어...        0.09
# 3                                        선호 직업 컴퓨터 화학        0.06
# 4          잡지 정보 뉴스 고갈 때문 유지 뉴스 원고 편집기자 사진작가 리포터 광고홍보        0.11
# 5   코드 익히는 멜로디 연주법 리듬주법 저출산 자동화 변화 때문 피크 엠프 컴퓨터 악보...        0.11
# 6    보육교사자격증 여성 사회 진출 증가 교재 도구 놀이 도구 선생님 피아노강사 아동복지보육        0.10
# 7                국제법이해 행정법 정보분석 대체 때문 한글 작성 엑셀 전자전기학과        0.12
# 8        내부 규정 이해 실제 사계교육 과거 비교 변화 때문 보안 장비 선생님 교정보호학        0.11
# 9              자동차 운전사 증가 대중교통 이용자 감소 버스기사 개인택시기사 상업고        0.10
# 10                  교회 합창단 거래처 구축 재봉틀 바로크 가위 의복수선 국문학        0.09
# 11                                 기계화 사람 연구 컴퓨터 화학공학        0.10
# 12                                   현대인 정신 갈등 목탁 불교학        0.08
# 13  소음진동기사 수질환경산업기사 법규 모델링 프로그램 전반 환경 규제 강화 추세 환경 ...        0.10
# 14           간호사 건강 관심 증가 주사기 간호사 복장 카트 체온계 환자 챠트 간호학        0.09
# 15                  주거 환경 건강 해충 방제 전문가 필요 포기 마스크 생명과학        0.09
# 16                  게임 산업 활성화 동반 프로그램 일러스트 포토샵 컴퓨터그래픽        0.11
# 17                            컴퓨터 대체 가위 볼펜 매직 검사원 인문계        0.09
# 18       마취전공 사람 확인 사항 기계로 페하 마취 주사 가운 마스크 마취 프리랜서 마취        0.09
# 19  워드 파워포인트 직무교육 자동화기 이메일 발송 인쇄 용지 인쇄기 재단 금속공작기계조...        0.12
# 20  기계경비지도사 컨트롤 장치등을 유지 관리 요령 컴퓨터 인공 지능 개발 때문 자동차 ...        0.12
# 21  워드프로세스1급 문서실무사1급 2종 소형운전면허증 견습 교육 우편물 감소 인원 감소...        0.11
# 22                                       점점 관심 장구 국악학        0.13
# 23                     업무 숙지 계속 배출 인원 언어 이클립스 컴퓨터정보공학        0.10
# 24  교감 자격증 중등교사 자격증 학급 수가 학교 수가 때문 엑셀 워드 파워포인트 교사 ...        0.09
# 25  전기 기계부품관련 전반적인 교육 제품 고객 만족 최우 선적 업무 이기 때문 프로그램...        0.10
# 26              베이비시터자격증 육아에 관련된 교육 인구 감소 저출산 산후조리사 이        0.61
# 27                          게임 시장 매출 증가 노트북 게임마케터 게임학        0.13
# 28                     자동차의 전반적 이해 산업 전문 기계화 전산 화로 기계        0.09
# 29  사회복지사 운전면허증 인력 원외 진행 협회 가입 예산 범위 사업 운영 시설 확대 엑...        0.12
# 30                         자동화 대형화 유리 가공 단기 아르곤 접기 전기        0.10
# 31                                    부동산 시장 영향 실내건축학        0.09
# 32             간호사면허증 응급대응훈련 업체 전문 간호사 채용 주사기 가운 간호학과        0.12
# 33                       전산 별로 영향 컴퓨터 계산기 경리 주부 사무자동화        0.10
# 34  사법연수원 이수 로스쿨 졸업생 증가 범죄 양상 증가 지식 검사 인력 수요 증가 법전...        0.11
# 35                  수화통역사 직무교육 수화 어법 제정 휴대폰 회사원 사회교육학        0.11
# 36         상권분석 세무회계관련된 훈련 창업 인구 때문 더존 주방일(요리사) 호텔조리학        0.14
# 37                               발달 수요 프로그램 리눅스 컴퓨터공학        0.08
# 38                               국내외 기술동향 에너지 개발 기계공학        0.13
# 39                    다양한교수법 대학 강사 추세 교재 학원강사 대학교수 사학        0.10
# 40   신기술 동향 파악 전기기본지식 무인 자동화 설비 구축 계측기 계전기 케이블 포선 공업계        0.10
# 41  예산집행관련 교육 발생 건수 경찰관 수가 실정 현실 증원 상황 것이므 수갑 가스총 ...        0.13
# 42                            사내업무교육 기계화 작업 기구 위생 기계과        0.11
# 43                                   인터넷 발전 컴퓨터 광고홍보학        0.09
# 44     글쓰는 구성 요령 글쓰는 기법 영화 환경 안정 증가 엑셀 원고지 일반행정직 문예창작        0.13
# 45                            모피 가죽 제품 인기 변화 가위 판매직 이        0.59
# 46          식품분석업무훈련 산업혁명 식품 연구 자동화 일자리 실험 도구 컴퓨터 물리학        0.10
# 47              철학관련 연구교육 최근 인문학 관심 증가 연구 자료 연구원 독일철학        0.09
# 48                       방수시공사 아파트 미분 사태 일감 흙손 수비 배달업        0.11
