# %% [markdown]
# # Train데이터 불러오기
#
# 각 년도별 DataFrame을 리스트에 append합니다.
#
# 리스트 인덱스별로
#
# 0: 2017년도 데이터
#
# 1: 2018년도 데이터
#
# 2: 2019년도 데이터
#
# 3: 202년도 데이터
#
# 입니다

# %%
import pandas as pd
from glob import glob
from tqdm import tqdm
import warnings

warnings.filterwarnings(action='ignore')
PATH_2017 = "./KNOW_data/train/KNOW_2017.csv"
PATH_2018 = "./KNOW_data/train/KNOW_2018.csv"
PATH_2019 = "./KNOW_data/train/KNOW_2019.csv"
PATH_2020 = "./KNOW_data/train/KNOW_2020.csv"

paths = [PATH_2017, PATH_2018, PATH_2019, PATH_2020]

know_train = [pd.read_csv(path) for path in paths]

# %%
know_train[0].head() # 2017년도 샘플
# Out:
#    idx  aq1_1 aq1_2  aq2_1 aq2_2  aq3_1 aq3_2  aq4_1 aq4_2  aq5_1  ... bq37  \
# 0    0      3     3      3     3      3     3      4     4      3  ...   52
# 1    1      4     5      4     5      3     4      3     4      3  ...   38
# 2    2      3     4      3     4      3     4      5     6      4  ...   50
# 3    3      3     3      3     3      3     5      4     5      4  ...   42
# 4    4      4     5      3     4      3     4      4     5      3  ...   51
#
#    bq38 bq38_1  bq39_1 bq39_2  bq40 bq41_1  bq41_2 bq41_3  knowcode
# 0     2     실업       1      1     1   4000           2200    825101
# 1     4   건축공학       1      1     1                  2400    140204
# 2     4   건축공학       1      1     1   4000           2400    140204
# 3     4   환경학과       1      1     1   7000           3500    140601
# 4     4   건축공학       1      1     1   4000           2500    140204
#
# [5 rows x 156 columns]

# %%
know_train[1].head() # 2018년도 샘플
# Out:
#     idx  cq1  cq2  cq3  cq4  cq5  cq6  cq7  cq8  cq9  ...  bq37_1  bq38  \
# 0  9486    5    3    4    2    2    5    4    5    4  ...    치기공과     1
# 1  9487    4    3    4    4    4    4    4    4    4  ...      이과     1
# 2  9488    4    1    5    3    3    4    2    4    1  ...     기계과     2
# 3  9489    4    3    4    4    4    3    3    2    3  ...   물리 과학     1
# 4  9490    3    2    3    1    1    4    3    4    3  ...    치기공학     1
#
#    bq38_1  bq38_2  bq39  bq40  bq41_1  bq41_2  bq41_3  knowcode
# 0       1             1    42    3800    3400            306301
# 1       2             1    40    2300    1800            133204
# 2               6        30.0                    3000    702502
# 3       1             1    40    3350    2750            121201
# 4       1             1    40    2500    2300            306301
#
# [5 rows x 141 columns]

# %%
know_train[2].head() # 2019년도 샘플
# Out:
#      idx  sq1  sq2  sq3  sq4  sq5  sq6  sq7  sq8  sq9  ...  bq27_1  bq28  \
# 0  18569    4    4    4    3    4    4    4    4    4  ...   기계공학과   1.0
# 1  18570    4    3    4    4    4    4    3    4    5  ...     경영학   2.0
# 2  18571    2    3    2    2    2    2    2    2    3  ...           2.0
# 3  18572    5    5    5    5    5    5    5    5    5  ...     행정학   1.0
# 4  18573    1    4    4    1    1    2    4    3    4  ...           2.0
#
#    bq28_1  bq28_2  bq29  bq30  bq31_1  bq31_2  bq31_3  knowcode
# 0       1             1    40    3500    3000            812301
# 1               5        40.0                    5000     15201
# 2               6          30                    3000    901101
# 3       1             1  40.0    3600    2400             29903
# 4               6          45                    1500    561401
#
# [5 rows x 153 columns]

# %%
know_train[3].head() # 2020년도 샘플
# Out:
#      idx  saq1_1 saq1_2  saq2_1 saq2_2  saq3_1 saq3_2  saq4_1 saq4_2  saq5_1  \
# 0  27127       4      4       4      4       4      5       4      5       3
# 1  27128       5      6       5      6       4      5       4      5       4
# 2  27129       3      4       3      4       3      4       3      5       3
# 3  27130       4      5       2      3       3      3       4      5       3
# 4  27131       5      6       4      5       3      5       4      4       4
#
#    ... bq26  bq26_1 bq27_1  bq27_2 bq28  bq29 bq30_1  bq30_2 bq30_3  knowcode
# 0  ...    4     간호학      1       1    1    40   4000    2600           304003
# 1  ...    4    기계공학      1       1    1    40   4000    3000           221401
# 2  ...    4      기계      1       1    1    48   4300    3000           815001
# 3  ...    4     보건학      1       1    1    40   3500    3300           304003
# 4  ...    4  건축설비공학      1       1    1    40   5700    2700           140201
#
# [5 rows x 185 columns]

# %%
know_train[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Columns: 156 entries, idx to knowcode
# dtypes: float64(1), int64(95), object(60)
# memory usage: 11.3+ MB

# %%
know_train[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9072 entries, 0 to 9071
# Columns: 141 entries, idx to knowcode
# dtypes: float64(69), int64(19), object(53)
# memory usage: 9.8+ MB

# %%
know_train[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8555 entries, 0 to 8554
# Columns: 153 entries, idx to knowcode
# dtypes: float64(27), int64(94), object(32)
# memory usage: 10.0+ MB

# %%
know_train[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8122 entries, 0 to 8121
# Columns: 185 entries, idx to knowcode
# dtypes: int64(129), object(56)
# memory usage: 11.5+ MB

# %%
len(know_train[0]['knowcode'].unique())
# Out:
# 538

# %%
len(know_train[1]['knowcode'].unique())
# Out:
# 576

# %%
len(know_train[2]['knowcode'].unique())
# Out:
# 559

# %%
len(know_train[3]['knowcode'].unique())
# Out:
# 537

# %%
know_train[1].columns[0:100]
# Out:
# Index(['idx', 'cq1', 'cq2', 'cq3', 'cq4', 'cq5', 'cq6', 'cq7', 'cq8', 'cq9',
#        'cq10', 'cq11', 'cq12', 'cq13', 'cq14', 'cq15', 'cq16', 'cq17', 'cq18',
#        'cq19', 'cq20', 'cq21', 'cq22', 'cq23', 'cq24', 'cq25', 'cq26', 'cq27',
#        'cq28', 'cq29', 'cq30', 'cq31', 'cq32', 'cq33', 'cq34', 'cq35', 'cq36',
#        'cq37', 'cq38', 'cq39', 'cq40', 'cq41', 'cq42', 'cq43', 'cq44', 'cq45',
#        'cq46', 'cq47', 'cq48', 'cq49', 'cq50_1', 'cq50_2', 'cq50_3', 'cq50_4',
#        'cq50_5', 'cq50_6', 'cq50_7', 'cq50_8', 'iq1', 'iq2', 'iq3', 'iq4',
#        'iq5', 'iq6', 'bq1', 'bq2', 'bq3', 'bq4', 'bq4_1a', 'bq4_1b', 'bq4_1c',
#        'bq5', 'bq5_1', 'bq5_2', 'bq6', 'bq7', 'bq8_1', 'bq8_2', 'bq8_3', 'bq9',
#        'bq10', 'bq11', 'bq12_1', 'bq12_2', 'bq12_3', 'bq12_4', 'bq12_5',
#        'bq13', 'bq14', 'bq15', 'bq16', 'bq17', 'bq18', 'bq19', 'bq20', 'bq21',
#        'bq221', 'bq222', 'bq223', 'bq231'],
#       dtype='object')

# %% [markdown]
# # 전처리
#
# 데이터의 빈 셀에 None값이 아닌 ' '처럼 공백으로 들어가있기 때문에 is_null등의 함수로 결측치를 찾아낼 수 없습니다.
#
# 공백이 있는 컬럼은 '0'으로 대체하였습니다.

# %%
for df in know_train:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# ## 라벨 인코딩
#
# 숫자로 변환할 수 있는 컬럼은 라벨 인코딩을 사용하지 않았습니다.
#
# string이나 object컬럼은 라벨인코더를 이용해 변환하였으며 추후 test셋에 사용해야하기 때문에 년도별, 컬럼별로 dictionary를 이용해 저장하였습니다

# %%
from sklearn.preprocessing import LabelEncoder
years = ['2017', '2018', '2019', '2020']

year_encoder = {}

for year, df in zip(years, know_train):
    print(year)
    encoders = {}
    
    for col in df.columns:
        if col == 'idx':
            print("HEY")
            continue
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = LabelEncoder()
            df[col] = df[col].map(str)
            df[col] = encoder.fit_transform(df[col])
            encoders[col] = encoder
            
            
    year_encoder[year] = encoders
# Out:
# 2017
# HEY
# 2018
# HEY
# 2019
# HEY
# 2020
# HEY

# %%
know_train[0]
# Out:
#        idx  aq1_1  aq1_2  aq2_1  aq2_2  aq3_1  aq3_2  aq4_1  aq4_2  aq5_1  \
# 0        0      3      3      3      3      3      3      4      4      3
# 1        1      4      5      4      5      3      4      3      4      3
# 2        2      3      4      3      4      3      4      5      6      4
# 3        3      3      3      3      3      3      5      4      5      4
# 4        4      4      5      3      4      3      4      4      5      3
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9481  9481      3      5      2      4      3      3      2      2      2
# 9482  9482      5      5      5      5      5      5      3      4      4
# 9483  9483      3      3      4      6      3      3      4      5      4
# 9484  9484      3      5      3      5      4      5      3      4      3
# 9485  9485      3      4      3      4      3      4      3      4      3
#
#       ...  bq37  bq38  bq38_1  bq39_1  bq39_2  bq40  bq41_1  bq41_2  bq41_3  \
# 0     ...    52     2     723       1       1     1     134       0      49
# 1     ...    38     4      33       1       1     1       0       0      57
# 2     ...    50     4      33       1       1     1     134       0      57
# 3     ...    42     4    1446       1       1     1     181       0      87
# 4     ...    51     4      33       1       1     1     134       0      59
# ...   ...   ...   ...     ...     ...     ...   ...     ...     ...     ...
# 9481  ...    50     4     543       1       1     1     158       0      33
# 9482  ...    37     4     862       1       1     1     134       0      74
# 9483  ...    32     2     216       1       4     2      88       0      23
# 9484  ...    40     4     384       1       1     1     179       0      59
# 9485  ...    48     3    1043       1       1     1     134       0      89
#
#       knowcode
# 0       825101
# 1       140204
# 2       140204
# 3       140601
# 4       140204
# ...        ...
# 9481    411301
# 9482    151105
# 9483    701101
# 9484     25402
# 9485     15201
#
# [9486 rows x 156 columns]

# %%
know_train[1]
# Out:
#         idx  cq1  cq2  cq3  cq4  cq5  cq6  cq7  cq8  cq9  ...  bq37_1  bq38  \
# 0      9486    5    3    4    2    2    5    4    5    4  ...    1551     1
# 1      9487    4    3    4    4    4    4    4    4    4  ...    1206     1
# 2      9488    4    1    5    3    3    4    2    4    1  ...     303     3
# 3      9489    4    3    4    4    4    3    3    2    3  ...     522     1
# 4      9490    3    2    3    1    1    4    3    4    3  ...    1552     1
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...   ...
# 9067  18564    5    5    5    2    2    4    2    5    3  ...    1684     4
# 9068  18565    5    5    5    3    3    5    4    4    4  ...     215     4
# 9069  18566    4    4    4    3    3    5    4    4    4  ...    1180     4
# 9070  18567    5    2    3    2    3    5    4    4    3  ...    1197     4
# 9071  18568    5    4    5    4    3    5    4    1    4  ...    1583     2
#
#       bq38_1  bq38_2  bq39  bq40  bq41_1  bq41_2  bq41_3  knowcode
# 0          1       0     1    62     157     114       0    306301
# 1          2       0     1    57      73      41       0    133204
# 2          0       4     0    36       0       0      45    702502
# 3          1       0     1    57     134      89       0    121201
# 4          1       0     1    57      86      70       0    306301
# ...      ...     ...   ...   ...     ...     ...     ...       ...
# 9067       0       4     0   108       0       0      24    303002
# 9068       0       4     0    89       0       0      67    615203
# 9069       0       3     0    54       0       0      89    301106
# 9070       0       3     0    98       0       0      74    301112
# 9071       1       0     1    57     176      91       0    133101
#
# [9072 rows x 141 columns]

# %%
know_train[2]
# Out:
#         idx  sq1  sq2  sq3  sq4  sq5  sq6  sq7  sq8  sq9  ...  bq27_1  bq28  \
# 0     18569    4    4    4    3    4    4    4    4    4  ...     308     0
# 1     18570    4    3    4    4    4    4    3    4    5  ...      80     1
# 2     18571    2    3    2    2    2    2    2    2    3  ...       0     1
# 3     18572    5    5    5    5    5    5    5    5    5  ...    1744     0
# 4     18573    1    4    4    1    1    2    4    3    4  ...       0     1
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...   ...
# 8550  27122    3    4    4    3    4    3    3    3    3  ...     587     0
# 8551  27123    5    5    4    4    4    5    4    4    5  ...    1765     0
# 8552  27124    3    3    4    4    4    4    4    3    3  ...     743     0
# 8553  27125    3    3    3    1    4    4    3    2    3  ...     301     0
# 8554  27126    5    5    5    5    5    3    3    4    4  ...    1709     0
#
#       bq28_1  bq28_2  bq29  bq30  bq31_1  bq31_2  bq31_3  knowcode
# 0          1       0     1    46     123      87       0    812301
# 1          0       3     0    47       0       0      71     15201
# 2          0       4     0    28       0       0      44    901101
# 3          1       0     1    47     127      66       0     29903
# 4          0       4     0    57       0       0      14    561401
# ...      ...     ...   ...   ...     ...     ...     ...       ...
# 8550       1       0     1    71     158      87       0    416105
# 8551       1       0     1    86     103      66       0    531601
# 8552       3       0     1    46      71      23       0    615301
# 8553       1       0     1    63     158      80       0    811901
# 8554       1       0     1    86     123      87       0    812101
#
# [8555 rows x 153 columns]

# %%
know_train[3]
# Out:
#         idx  saq1_1  saq1_2  saq2_1  saq2_2  saq3_1  saq3_2  saq4_1  saq4_2  \
# 0     27127       4       4       4       4       4       5       4       5
# 1     27128       5       6       5       6       4       5       4       5
# 2     27129       3       4       3       4       3       4       3       5
# 3     27130       4       5       2       3       3       3       4       5
# 4     27131       5       6       4       5       3       5       4       4
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 8117  35244       4       6       3       5       3       3       1       0
# 8118  35245       3       4       4       5       2       4       4       6
# 8119  35246       5       6       3       4       3       4       4       5
# 8120  35247       5       6       5       5       4       5       3       3
# 8121  35248       2       5       4       6       3       5       4       5
#
#       saq5_1  ...  bq26  bq26_1  bq27_1  bq27_2  bq28  bq29  bq30_1  bq30_2  \
# 0          3  ...     4       9       1       1     1    40     194      71
# 1          4  ...     4     166       1       1     1    40     194     100
# 2          3  ...     4     161       1       1     1    48     215     100
# 3          3  ...     4     368       1       1     1    40     152     118
# 4          4  ...     4      22       1       1     1    40     271      78
# ...      ...  ...   ...     ...     ...     ...   ...   ...     ...     ...
# 8117       5  ...     6     890       1       1     1    40     255     140
# 8118       1  ...     4      96       1       1     1    45     117      71
# 8119       5  ...     4     114       1       1     1    40     306     100
# 8120       3  ...     5    1069       1       1     1    40     271     113
# 8121       3  ...     3     867       1       1     1    46     168      78
#
#       bq30_3  knowcode
# 0          0    304003
# 1          0    221401
# 2          0    815001
# 3          0    304003
# 4          0    140201
# ...      ...       ...
# 8117       0    121105
# 8118       0     26102
# 8119       0     31301
# 8120       0    154105
# 8121       0     14201
#
# [8122 rows x 185 columns]

# %% [markdown]
# # X, y 구분 및 모델 학습
#
# 이번 대회에서 맞춰야 할 값은 knowcode입니다.
#
# ID와 knowcode를 제외한 나머지 feature를 X, knowcode를 정답 y로 두어 모델을 학습하였습니다.
#
# 베이스라인에서는 의사결정나무와 랜덤포레스트를 선정하였습니다

# %%
know_train[0].iloc[:, 1:-1]
# Out:
#       aq1_1  aq1_2  aq2_1  aq2_2  aq3_1  aq3_2  aq4_1  aq4_2  aq5_1  aq5_2  \
# 0         3      3      3      3      3      3      4      4      3      4
# 1         4      5      4      5      3      4      3      4      3      4
# 2         3      4      3      4      3      4      5      6      4      5
# 3         3      3      3      3      3      5      4      5      4      6
# 4         4      5      3      4      3      4      4      5      3      4
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9481      3      5      2      4      3      3      2      2      2      3
# 9482      5      5      5      5      5      5      3      4      4      5
# 9483      3      3      4      6      3      3      4      5      4      5
# 9484      3      5      3      5      4      5      3      4      3      5
# 9485      3      4      3      4      3      4      3      4      3      4
#
#       ...  bq36  bq37  bq38  bq38_1  bq39_1  bq39_2  bq40  bq41_1  bq41_2  \
# 0     ...     1    52     2     723       1       1     1     134       0
# 1     ...     1    38     4      33       1       1     1       0       0
# 2     ...     1    50     4      33       1       1     1     134       0
# 3     ...     1    42     4    1446       1       1     1     181       0
# 4     ...     1    51     4      33       1       1     1     134       0
# ...   ...   ...   ...   ...     ...     ...     ...   ...     ...     ...
# 9481  ...     1    50     4     543       1       1     1     158       0
# 9482  ...     1    37     4     862       1       1     1     134       0
# 9483  ...     1    32     2     216       1       4     2      88       0
# 9484  ...     2    40     4     384       1       1     1     179       0
# 9485  ...     1    48     3    1043       1       1     1     134       0
#
#       bq41_3
# 0         49
# 1         57
# 2         57
# 3         87
# 4         59
# ...      ...
# 9481      33
# 9482      74
# 9483      23
# 9484      59
# 9485      89
#
# [9486 rows x 154 columns]

# %%
train_data = {}
for year, df in zip(years, know_train):
    train_data[year] = {'X': df.iloc[:, 1:-1], # idx 제외
                        'y': df.iloc[:, -1]}

# %%
RANDOM_STATE = 42

# %% [markdown]
# ## 의사결정나무

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

dt_models = {}

for year in tqdm(years):
    model = DecisionTreeClassifier(random_state=RANDOM_STATE)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    dt_models[year] = model
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:13<00:00,  3.25s/it]

# %% [markdown]
# ## 랜덤포레스트

# %%
rf_models = {}

for year in tqdm(years):
    model = RandomForestClassifier(n_estimators=100, random_state=RANDOM_STATE, n_jobs=8)
    model.fit(train_data[year]['X'].iloc[:, :], train_data[year]['y'])
    rf_models[year] = model
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [01:11<00:00, 17.79s/it]

# %% [markdown]
# ## Testset 불러오기
#
# 마찬가지로 년도별로 DataFrame으로 불러온 후 리스트에 할당합니다.

# %%
TEST_PATH_2017 = "./KNOW_data/test/KNOW_2017_test.csv"
TEST_PATH_2018 = "./KNOW_data/test/KNOW_2018_test.csv"
TEST_PATH_2019 = "./KNOW_data/test/KNOW_2019_test.csv"
TEST_PATH_2020 = "./KNOW_data/test/KNOW_2020_test.csv"

TEST_PATHs = [TEST_PATH_2017, TEST_PATH_2018, TEST_PATH_2019, TEST_PATH_2020]

# %%
know_test = [pd.read_csv(path) for path in TEST_PATHs]
know_test[0].head() # 2017년도 test 샘플
# Out:
#    idx  aq1_1 aq1_2  aq2_1 aq2_2  aq3_1 aq3_2  aq4_1 aq4_2  aq5_1  ... bq36  \
# 0    0      3     4      2     2      3     3      1            3  ...    2
# 1    1      5     5      3     5      5     5      5     5      4  ...    1
# 2    2      5     5      5     4      5     4      1            1  ...    1
# 3    3      4     5      5     6      4     6      3     4      4  ...    1
# 4    4      5     6      4     5      4     5      1            1  ...    1
#
#    bq37 bq38  bq38_1 bq39_1  bq39_2 bq40  bq41_1 bq41_2  bq41_3
# 0    26    3     비서학      1       1    1    3000           2300
# 1    57    4     농화학      1       1    1    5500           2500
# 2    31    4    신문방송      1       1    1    4300           4000
# 3    35    6      화학      1       1    1    4100           3000
# 4    36    4    광고홍보      1       1    1    2800           2000
#
# [5 rows x 155 columns]

# %% [markdown]
# Train set과 마찬가지로 평균, '0'으로 대체하였습니다

# %%
for df in know_test:
    for col in df.columns:
        df[col].replace(' ', '0', inplace=True)

# %% [markdown]
# Train에 사용하였던 라벨인코더를 이용해서 카테고리를 정수로 변환합니다.
#
# 만약 Test변수가 Train 라벨인코더의 클래스에 없을경우 -1로 처리합니다

# %%
years = ['2017', '2018', '2019', '2020']

for year, df in zip(years, know_test):
    print(year)
    encoders = {}
    
    for col in df.columns:
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = year_encoder[year][col]
            df[col] = df[col].map(str)
            category_map = {category: idx for idx, category in enumerate(encoder.classes_)}
            df[col] = df[col].apply(lambda x: category_map[x] if x in category_map else -1) # train set에서 보지못한 카테고리변수 -1(UNK) 처리
# Out:
# 2017
# 2018
# 2019
# 2020

# %% [markdown]
# ### 데이터 처리 및 라벨인코딩 후

# %%
know_train[0]['aq1_1'].value_counts()
# Out:
# 3    3116
# 4    3007
# 2    1706
# 5    1072
# 1     585
# Name: aq1_1, dtype: int64

# %%
know_test[0].head() # 2017년도 test 샘플
# Out:
#    idx  aq1_1  aq1_2  aq2_1  aq2_2  aq3_1  aq3_2  aq4_1  aq4_2  aq5_1  ...  \
# 0    0      3      4      2      2      3      3      1      0      3  ...
# 1    1      5      5      3      5      5      5      5      5      4  ...
# 2    2      5      5      5      4      5      4      1      0      1  ...
# 3    3      4      5      5      6      4      6      3      4      4  ...
# 4    4      5      6      4      5      4      5      1      0      1  ...
#
#    bq36  bq37  bq38  bq38_1  bq39_1  bq39_2  bq40  bq41_1  bq41_2  bq41_3
# 0     2    26     3     497       1       1     1    3000       0    2300
# 1     1    57     4     287       1       1     1    5500       0    2500
# 2     1    31     4     705       1       1     1    4300       0    4000
# 3     1    35     6    1423       1       1     1    4100       0    3000
# 4     1    36     4     141       1       1     1    2800       0    2000
#
# [5 rows x 155 columns]

# %% [markdown]
# ## 테스트셋 추출 및 학습
#
# ID 값을 제외한 나머지 데이터를 이용하여 모델에 넣어 추론합니다.

# %%
test_data = {}
for year, df in zip(years, know_test):
    test_data[year] =  {'X': df.iloc[:,1:]}

# %% [markdown]
# ### 의사결정나무로 예측

# %%
dt_predicts = [] 

for year in tqdm(years):
    pred = dt_models[year].predict(test_data[year]['X'])
    dt_predicts.extend(pred)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  9.05it/s]

# %% [markdown]
# ### 랜덤포레스트로 예측

# %%
rf_predicts = [] 

for year in tqdm(years):
    pred = rf_models[year].predict(test_data[year]['X'])
    rf_predicts.extend(pred)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:38<00:00,  9.58s/it]

# %% [markdown]
# # 제출

# %%
submission = pd.read_csv('./KNOW_data/sample_submission.csv') # sample submission 불러오기

# %%
submission['knowcode'] = rf_predicts

submission.to_csv('submission_baseline.csv', index=False)
